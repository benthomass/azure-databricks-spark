# %%
# 1. Define your Tenant and Client IDs (paste your actual GUID strings here)
tenant_id = "c4630979-2626-453e-8851-3d75ab706c42"
client_id = "1bef13e4-2560-4f87-9d08-bdfea208bc3f"

# 2. Fetch the Secret securely from your Key Vault scope!
# (Replace 'adls-secret-name' with the exact Secret Name you gave it inside Azure Key Vault)
client_secret = dbutils.secrets.get(scope="formula1-kv-scope", key="databricks-client-secret")

# 3. Configure Spark Session
spark.conf.set("fs.azure.account.auth.type.dbcourse2026storage.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.dbcourse2026storage.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.dbcourse2026storage.dfs.core.windows.net", client_id)
spark.conf.set("fs.azure.account.oauth2.client.secret.dbcourse2026storage.dfs.core.windows.net", client_secret)
spark.conf.set("fs.azure.account.oauth2.client.endpoint.dbcourse2026storage.dfs.core.windows.net", f"https://login.microsoftonline.com/{tenant_id}/oauth2/token")

# %%
display(dbutils.fs.ls("abfss://formula1@dbcourse2026storage.dfs.core.windows.net/"))

# %%
raw_folder_path = "abfss://formula1@dbcourse2026storage.dfs.core.windows.net/raw/"
processed_folder_path = "abfss://formula1@dbcourse2026storage.dfs.core.windows.net/processed/"
presentation_folder_path = "abfss://formula1@dbcourse2026storage.dfs.core.windows.net/presentation/"
