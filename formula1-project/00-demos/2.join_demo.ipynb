# %%
# %run "../01-setup/1.configure_access_to_cloud_storage"

# %%
circuits_df = spark.read.parquet(f"{processed_folder_path}/circuits").withColumnRenamed("name", "circuit_name")
display(circuits_df)
races_df = spark.read.parquet(f"{processed_folder_path}/races").filter("race_year = 2018").withColumnRenamed("name", "race_name")
display(races_df)
drivers_df = spark.read.parquet(f"{processed_folder_path}/drivers")

# %% [markdown]
# ## Inner join

# %%
race_circuits_df = circuits_df.join(races_df, circuits_df.circuit_id == races_df.circuit_id, "inner") \
  .select(circuits_df.circuit_name, circuits_df.location, circuits_df.country, races_df.race_name, races_df.round)
display(race_circuits_df)

# %% [markdown]
# ## Outer join

# %%
circuits_df = spark.read.parquet(f"{processed_folder_path}/circuits") \
  .filter("circuit_id < 70") \
  .withColumnRenamed("name", "circuit_name")

# %%
race_circuits_df = circuits_df.join(races_df, circuits_df.circuit_id == races_df.circuit_id, "outer") \
  .select(circuits_df.circuit_name, circuits_df.location, circuits_df.country, races_df.race_name, races_df.round)
display(race_circuits_df)

# %% [markdown]
# ## Semi joins

# %%
race_circuits_df = circuits_df.join(races_df, circuits_df.circuit_id == races_df.circuit_id, "semi") \
  .select(circuits_df.circuit_name, circuits_df.location, circuits_df.country)
display(race_circuits_df)

# %% [markdown]
# ## Anti join

# %%
race_circuits_df = races_df.join(circuits_df, circuits_df.circuit_id == races_df.circuit_id, "anti")
display(race_circuits_df)

# %% [markdown]
# ## Cross joins

# %%
race_circuits_df = races_df.crossJoin(circuits_df)
display(race_circuits_df)
