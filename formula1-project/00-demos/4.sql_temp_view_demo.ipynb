# %%
# %run "../01-setup/1.configure_access_to_cloud_storage"

# %%
df = spark.read.parquet(f"{presentation_folder_path}/race_results")

# %%
df.createOrReplaceTempView("race_results_view")

# %%
# %sql 
SELECT driver_name from race_results_view
WHERE race_year = 2019

# %%
year = 2019
races_df = spark.sql(f"SELECT * FROM race_results_view WHERE race_year = {year}")
display(races_df)

# %%
df.createOrReplaceGlobalTempView("gb_race_results")

# %%
# %sql
SHOW TABLES IN global_temp;

# %%
# %sql
SELECT * FROM global_temp.gb_race_results

# %%
spark.sql("SELECT  * FROM global_temp.gb_race_results").show()
